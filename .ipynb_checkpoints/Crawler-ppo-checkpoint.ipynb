# %% [markdown]
# ### 1. Start the Environment

# %%
from gym_unity.envs import UnityEnv
import numpy as np

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Reacher Unity environment.
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env_name = 'unity_envs/Crawler_StaticTarget_Linux/Crawler_StaticTarget_Linux.x86_64'
env = UnityEnv(env_name,worker_id=1,use_visual=False, multiagent=True)
# Out:
# INFO:mlagents.envs:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of Training Brains : 1
#         Reset Parameters :
#
# Unity brain name: CrawlerStaticLearning
#         Number of Visual Observations (per agent): 0
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): [20]
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,
# INFO:gym_unity:12 agents within environment.

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# * Set-up: A creature with 4 arms and 4 forearms.
# * Goal: The agents must move its body toward the goal direction without falling.
# * CrawlerStaticTarget - Goal direction is always forward.
# * CrawlerDynamicTarget- Goal direction is randomized.
# * Agents: The environment contains 3 agent linked to a single Brain.
# * Agent Reward Function (independent):
# * +0.03 times body velocity in the goal direction.
# * +0.01 times body direction alignment with goal direction.
# * Brains: One Brain with the following observation/action space.
# * Vector Observation space: 117 variables corresponding to position, rotation, velocity, and angular velocities of each limb plus the acceleration and angular acceleration of the body.
# * Vector Action space: (Continuous) Size of 20, corresponding to target rotations for joints.
# * Visual Observations: None.
# * Reset Parameters: None
# * Benchmark Mean Reward for CrawlerStaticTarget: 2000
# * Benchmark Mean Reward for CrawlerDynamicTarget: 400
#
# Lets print some information about the environment.

# %%
# number of agents
num_agents = env.number_agents
print('Number of agents:', num_agents)

# size of each action
action_size = env.action_space.shape[0]
print('Size of each action:', action_size)

# examine the state space 
states = env.reset()
state_size = env.observation_space.shape[0]
print('There are {} agents. Each observes a state with length: {}'.format(num_agents, state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 9.99999225e-01  1.27272622e-03  0.00000000e+00  2.25000000e+00
#   1.00000036e+00 -3.22882910e-12 -1.19209290e-07  3.22882975e-12
#   1.00000000e+00 -3.22882910e-12  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  5.00000000e-01
#   5.00000000e-01  0.00000000e+00  5.00000000e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339918e+00 -1.42857209e-01
#  -1.33341408e+00  5.00000000e-01  0.00000000e+00  0.00000000e+00
#   5.00000000e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093287e-01 -1.42857209e-01 -6.06078684e-01  5.00000000e-01
#   5.00000000e-01  0.00000000e+00  5.00000000e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339942e+00 -1.42857209e-01
#  -1.33341372e+00  5.00000000e-01  0.00000000e+00  0.00000000e+00
#   5.00000000e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  5.00000000e-01
#   5.00000000e-01  0.00000000e+00  5.00000000e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339918e+00 -1.42857209e-01
#   1.33341420e+00  5.00000000e-01  0.00000000e+00  0.00000000e+00
#   5.00000000e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093287e-01 -1.42857209e-01  6.06078684e-01  5.00000000e-01
#   5.00000000e-01  0.00000000e+00  5.00000000e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339942e+00 -1.42857209e-01
#   1.33341384e+00  5.00000000e-01  0.00000000e+00  0.00000000e+00
#   5.00000000e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment

# %%
states = env.reset()                 # reset env and get the current state (for each agent)
scores = np.zeros(num_agents)        # initialize the score (for each agent)
step=0
while True:
    # select an action (for each agent)
    actions = list(2*np.random.rand(num_agents, action_size)-1)
    next_states,rewards,dones,_ = env.step(actions)    
    
    # update the score (for each agent)
    scores +=  rewards
    
    # roll over states to next time step
    states = next_states                               
    step+=1
    
    # exit loop if episode finished
    if np.any(dones):                                  
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 1.1957619555372123

# %% [markdown]
# ### 4. Training the agent!
#
# Now it's turn to train an agent to solve the environment!  When training the environment, we have to set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
import random
import datetime
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

#pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal

# imports for rendering outputs in Jupyter.
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# defining the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print ("using",device)
# Out:
# using cuda:0

# %% [markdown]
# ### 3. Define policy network (Actor Critic style)

# %%
action_low = env.action_space.low
action_high = env.action_space.high

# define actor critic network
class ActorCritic(nn.Module):
    
    def __init__(self,state_size,action_size,action_high,action_low,hidden_size=32):
        super(ActorCritic, self).__init__()
        
        # action range
        self.action_high = torch.tensor(action_high).to(device)
        self.action_low = torch.tensor(action_low).to(device)
        
        self.std = nn.Parameter(torch.zeros(action_size))
        
        # common network
        self.fc1 = nn.Linear(state_size,512)
        
        # actor network
        self.fc2_actor = nn.Linear(512,256)
        self.fc3_action = nn.Linear(256,action_size)
        #self.fc3_std = nn.Linear(64,action_size)
        
        # critic network
        self.fc2_critic = nn.Linear(512,64)
        self.fc3_critic = nn.Linear(64,1)
    
    def forward(self,state):
        # common network
        x = F.relu(self.fc1(state))
        
        # actor network
        x_actor = F.relu(self.fc2_actor(x))
        action_mean = F.sigmoid(self.fc3_action(x_actor))
        ## rescale action mean
        action_mean_ = (self.action_high-self.action_low)*action_mean + self.action_low
        #action_std = F.sigmoid(self.fc3_std(x_actor))
        
        # critic network
        x_critic = F.relu(self.fc2_critic(x))
        v = self.fc3_critic(x_critic)
        return action_mean_,v
    
    def act(self,state,action=None):
        # converting state from numpy array to pytorch tensor on the "device"
        state = torch.from_numpy(state).float().to(device)
        action_mean,v = self.forward(state)
        prob_dist = Normal(action_mean,F.softplus(self.std))
        if action is None:
            action = prob_dist.sample()
        log_prob = prob_dist.log_prob(action).sum(-1).unsqueeze(-1)
        entropy = prob_dist.entropy().sum(-1).unsqueeze(-1)
        return {'a': action,
                'log_pi_a': log_prob,
                'ent': entropy,
                'mean': action_mean,
                'v': v}

# %% [markdown]
# ### 4. Storage class

# %%
class Storage:
    def __init__(self, size, keys=None):
        if keys is None:
            keys = []
        keys = keys + ['s', 'a', 'r', 'm',
                       'v', 'q', 'pi', 'log_pi', 'ent',
                       'adv', 'ret', 'q_a', 'log_pi_a',
                       'mean']
        self.keys = keys
        self.size = size
        self.reset()

    def add(self, data):
        for k, v in data.items():
            assert k in self.keys
            getattr(self, k).append(v)

    def placeholder(self):
        for k in self.keys:
            v = getattr(self, k)
            if len(v) == 0:
                setattr(self, k, [None] * self.size)

    def reset(self):
        for key in self.keys:
            setattr(self, key, [])

    def cat(self, keys):
        data = [getattr(self, k)[:self.size] for k in keys]
        return map(lambda x: torch.cat(x, dim=0), data)

# %% [markdown]
# ### 4. PPO agent

# %%
from collections import deque
from itertools import accumulate
import torch.tensor as tensor

def random_sample(indices, batch_size):
    indices = np.asarray(np.random.permutation(indices))
    batches = indices[:len(indices) // batch_size * batch_size].reshape(-1, batch_size)
    for batch in batches:
        yield batch
    r = len(indices) % batch_size
    if r:
        yield indices[-r:]
        
class Agent:
    
    def __init__(self,env,learning_rate=1e-3):
        self.env = env
        nS = state_size
        nA = action_size
        self.policy = ActorCritic(state_size=nS,hidden_size=128,action_size=nA,
                             action_low=action_low,action_high=action_high).to(device)
        self.optimizer = optim.RMSprop(self.policy.parameters(), lr=learning_rate)
        
        # reset the environment
        self.states = np.array(env.reset())
        
        self.episode_rewards_window = deque(maxlen=100)
        self.episode_rewards = []
        num_trajectories = 12
        self.online_rewards = np.zeros(num_trajectories)
    
        
    def train(self,max_opt_steps=1000,num_trajectories=12,rollout_length=2048,mini_batch_size=64,gamma=.99,
              target_score=-250,use_gae=False,gae_tau=0.95,PRINT_EVERY=100):
        
        for opt_step in range(max_opt_steps):
        
            storage = Storage(rollout_length)
            states = self.states
            for _ in range(rollout_length):
                prediction = self.policy.act(states)
                
                # send all actions to tne environment
                next_states,rewards,terminals,_ = self.env.step(list(prediction['a'].cpu().numpy()))
                
                next_states = np.array(next_states)
                rewards = np.array(rewards)                   
                terminals = np.array(terminals)
                
                self.online_rewards += rewards
                for i, terminal in enumerate(terminals):
                    if terminals[i]:
                        self.episode_rewards.append(self.online_rewards[i])
                        self.episode_rewards_window.append(self.online_rewards[i])
                        self.online_rewards[i] = 0
                
                storage.add(prediction)
                storage.add({'r': tensor(rewards).unsqueeze(-1).float().to(device),
                             'm': tensor(1 - terminals).unsqueeze(-1).float().to(device),
                             's': tensor(states).to(device)})
                states = next_states

            self.states = states
            prediction = self.policy.act(states)
            storage.add(prediction)
            storage.placeholder()

            advantages = tensor(np.zeros((num_trajectories, 1))).float().to(device)
            returns = prediction['v'].detach()
            for i in reversed(range(rollout_length)):
                returns = storage.r[i] + gamma * storage.m[i] * returns
                if not use_gae:
                    advantages = returns - storage.v[i].detach()
                else:
                    td_error = storage.r[i] + gamma * storage.m[i] * storage.v[i + 1] - storage.v[i]
                    advantages = advantages * gae_tau * gamma * storage.m[i] + td_error
                storage.adv[i] = advantages.detach()
                storage.ret[i] = returns.detach()

            states, actions, log_probs_old, returns, advantages = storage.cat(['s', 'a', 'log_pi_a', 'ret', 'adv'])
            actions = actions.detach()
            log_probs_old = log_probs_old.detach()
            advantages = (advantages - advantages.mean()) / advantages.std()
            
            ppo_ratio_clip = 0.2
            gradient_clip = 0.5
            entropy_weight = 0.0
            
            for _ in range(10):
                sampler = random_sample(np.arange(states.size(0)), mini_batch_size)
                for batch_indices in sampler:
                    batch_indices = tensor(batch_indices).long()
                    sampled_states = states[batch_indices]
                    sampled_actions = actions[batch_indices]
                    sampled_log_probs_old = log_probs_old[batch_indices]
                    sampled_returns = returns[batch_indices]
                    sampled_advantages = advantages[batch_indices]

                    prediction = self.policy.act(sampled_states.cpu().numpy(), sampled_actions)
                    ratio = (prediction['log_pi_a'] - sampled_log_probs_old).exp()
                    obj = ratio * sampled_advantages
                    obj_clipped = ratio.clamp(1.0 - ppo_ratio_clip,
                                              1.0 + ppo_ratio_clip) * sampled_advantages
                    policy_loss = -torch.min(obj, obj_clipped).mean() - entropy_weight * prediction['ent'].mean()

                    value_loss = 0.5 * (sampled_returns - prediction['v']).pow(2).mean()

                    self.optimizer.zero_grad()
                    (policy_loss + value_loss).backward()
                    nn.utils.clip_grad_norm_(self.policy.parameters(), gradient_clip)
                    self.optimizer.step()
            
            #printing progress
            if opt_step % PRINT_EVERY == 0:
                print ("Opt step: {}\t Avg reward: {:.2f}\t std: {}".format(opt_step,np.mean(self.episode_rewards_window),
                                                                             self.policy.std))
                # save the policy
                torch.save(self.policy, 'ppo-crawler.policy')
            
            if np.mean(self.episode_rewards_window)>= target_score:
                print ("Environment solved in {} optimization steps! ... Avg reward : {:.2f}".format(opt_step-100,
                                                                                          np.mean(self.episode_rewards_window)))
                # save the policy
                torch.save(self.policy, 'ppo-crawler.policy')
                break
                
        return self.episode_rewards

# %% [markdown]
# ### 5. Train the agent

# %%
# lets define and train our agent
agent = Agent(env=env,learning_rate=1e-4)

# %%
scores = agent.train(max_opt_steps=2000,gamma=0.98,target_score=2000,use_gae=True,PRINT_EVERY=1)
# Out:
# /home/g1jaskiratsingh/anaconda3/envs/cv3/lib/python3.6/site-packages/torch/nn/functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Opt step: 0	 Avg reward: -2.61	 std: Parameter containing:
# tensor([ 0.0008, -0.0070, -0.0049, -0.0037,  0.0023, -0.0050, -0.0047,  0.0094,
#         -0.0068,  0.0006, -0.0048, -0.0010,  0.0019, -0.0048,  0.0026, -0.0032,
#         -0.0091,  0.0024,  0.0021, -0.0078], device='cuda:0',
#        requires_grad=True)
# /home/g1jaskiratsingh/anaconda3/envs/cv3/lib/python3.6/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type ActorCritic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Opt step: 1	 Avg reward: -0.26	 std: Parameter containing:
# tensor([-0.0002, -0.0093, -0.0105, -0.0044, -0.0013, -0.0031, -0.0051,  0.0097,
#         -0.0046, -0.0035, -0.0014, -0.0022, -0.0058, -0.0033, -0.0010, -0.0046,
#         -0.0082, -0.0012,  0.0046, -0.0042], device='cuda:0',
#        requires_grad=True)
# Opt step: 2	 Avg reward: 4.48	 std: Parameter containing:
# tensor([-0.0026, -0.0084, -0.0094, -0.0072, -0.0047, -0.0020, -0.0079,  0.0087,
#         -0.0102, -0.0122,  0.0002,  0.0009, -0.0049, -0.0087,  0.0034, -0.0069,
#         -0.0054, -0.0098, -0.0078, -0.0079], device='cuda:0',
#        requires_grad=True)
# Opt step: 3	 Avg reward: 5.29	 std: Parameter containing:
# tensor([-1.0853e-02, -1.4654e-02, -1.1256e-02, -5.3427e-03, -6.3788e-03,
#         -4.6587e-05, -3.6881e-03, -1.3093e-03, -1.3239e-02, -1.6244e-02,
#         -3.5796e-03, -4.7262e-03, -1.4249e-02, -1.4963e-02,  8.9431e-04,
#         -1.2529e-02, -1.4089e-02, -7.1098e-03, -3.7697e-03, -1.1113e-02],
#        device='cuda:0', requires_grad=True)
# Opt step: 4	 Avg reward: 8.52	 std: Parameter containing:
# tensor([-0.0091, -0.0130, -0.0109, -0.0013, -0.0073, -0.0015, -0.0083, -0.0060,
#         -0.0173, -0.0169, -0.0104, -0.0048, -0.0158, -0.0187, -0.0072, -0.0113,
#         -0.0213, -0.0061,  0.0008, -0.0080], device='cuda:0',
#        requires_grad=True)
# Opt step: 5	 Avg reward: 11.44	 std: Parameter containing:
# tensor([-0.0116, -0.0097, -0.0097, -0.0050, -0.0108, -0.0008, -0.0104, -0.0080,
#         -0.0180, -0.0210, -0.0215, -0.0153, -0.0175, -0.0142, -0.0077, -0.0182,
#         -0.0236, -0.0121,  0.0005, -0.0082], device='cuda:0',
#        requires_grad=True)
# Opt step: 6	 Avg reward: 12.47	 std: Parameter containing:
# tensor([-0.0144, -0.0133, -0.0091, -0.0074, -0.0160, -0.0070, -0.0188, -0.0096,
#         -0.0126, -0.0256, -0.0179, -0.0210, -0.0226, -0.0218, -0.0096, -0.0198,
#         -0.0365, -0.0081, -0.0072, -0.0031], device='cuda:0',
#        requires_grad=True)
# Opt step: 7	 Avg reward: 13.52	 std: Parameter containing:
# tensor([-0.0119, -0.0149, -0.0148, -0.0144, -0.0152, -0.0127, -0.0171, -0.0206,
#         -0.0141, -0.0228, -0.0166, -0.0244, -0.0266, -0.0209, -0.0128, -0.0228,
#         -0.0373, -0.0132, -0.0130, -0.0129], device='cuda:0',
#        requires_grad=True)
# Opt step: 8	 Avg reward: 19.02	 std: Parameter containing:
# tensor([-0.0122, -0.0193, -0.0122, -0.0165, -0.0160, -0.0180, -0.0214, -0.0238,
#         -0.0216, -0.0280, -0.0234, -0.0280, -0.0241, -0.0241, -0.0107, -0.0256,
#         -0.0397, -0.0119, -0.0160, -0.0135], device='cuda:0',
#        requires_grad=True)
# Opt step: 9	 Avg reward: 15.74	 std: Parameter containing:
# tensor([-0.0081, -0.0246, -0.0096, -0.0155, -0.0189, -0.0194, -0.0160, -0.0272,
#         -0.0238, -0.0213, -0.0299, -0.0317, -0.0175, -0.0243, -0.0199, -0.0277,
#         -0.0453, -0.0063, -0.0241, -0.0126], device='cuda:0',
#        requires_grad=True)
# Opt step: 10	 Avg reward: 16.92	 std: Parameter containing:
# tensor([-0.0115, -0.0278, -0.0064, -0.0213, -0.0168, -0.0194, -0.0159, -0.0275,
#         -0.0264, -0.0260, -0.0280, -0.0319, -0.0184, -0.0255, -0.0285, -0.0258,
#         -0.0448, -0.0091, -0.0256, -0.0219], device='cuda:0',
#        requires_grad=True)
# Opt step: 11	 Avg reward: 18.44	 std: Parameter containing:
# tensor([-0.0094, -0.0290, -0.0062, -0.0215, -0.0173, -0.0222, -0.0184, -0.0337,
#         -0.0308, -0.0301, -0.0298, -0.0421, -0.0230, -0.0226, -0.0360, -0.0279,
#         -0.0475, -0.0090, -0.0317, -0.0252], device='cuda:0',
#        requires_grad=True)
# Opt step: 12	 Avg reward: 17.44	 std: Parameter containing:
# tensor([-0.0149, -0.0214, -0.0137, -0.0291, -0.0175, -0.0292, -0.0140, -0.0363,
#         -0.0362, -0.0377, -0.0350, -0.0474, -0.0250, -0.0258, -0.0451, -0.0306,
#         -0.0520, -0.0178, -0.0300, -0.0340], device='cuda:0',
#        requires_grad=True)
# Opt step: 13	 Avg reward: 24.31	 std: Parameter containing:
# tensor([-0.0108, -0.0195, -0.0188, -0.0298, -0.0251, -0.0395, -0.0164, -0.0399,
#         -0.0435, -0.0334, -0.0381, -0.0567, -0.0207, -0.0228, -0.0417, -0.0260,
#         -0.0562, -0.0227, -0.0295, -0.0387], device='cuda:0',
#        requires_grad=True)
# Opt step: 14	 Avg reward: 24.44	 std: Parameter containing:
# tensor([-0.0105, -0.0211, -0.0225, -0.0267, -0.0322, -0.0439, -0.0176, -0.0395,
#         -0.0470, -0.0411, -0.0398, -0.0671, -0.0223, -0.0208, -0.0516, -0.0271,
#         -0.0600, -0.0305, -0.0332, -0.0394], device='cuda:0',
#        requires_grad=True)
# Opt step: 15	 Avg reward: 25.16	 std: Parameter containing:
# tensor([-0.0210, -0.0251, -0.0307, -0.0338, -0.0377, -0.0495, -0.0269, -0.0423,
#         -0.0430, -0.0495, -0.0443, -0.0686, -0.0235, -0.0257, -0.0566, -0.0295,
#         -0.0651, -0.0371, -0.0376, -0.0422], device='cuda:0',
#        requires_grad=True)
# Opt step: 16	 Avg reward: 22.28	 std: Parameter containing:
# tensor([-0.0222, -0.0245, -0.0315, -0.0408, -0.0351, -0.0533, -0.0274, -0.0488,
#         -0.0357, -0.0432, -0.0431, -0.0734, -0.0246, -0.0283, -0.0571, -0.0372,
#         -0.0649, -0.0421, -0.0366, -0.0386], device='cuda:0',
#        requires_grad=True)
# Opt step: 17	 Avg reward: 26.67	 std: Parameter containing:
# tensor([-0.0209, -0.0249, -0.0374, -0.0456, -0.0439, -0.0531, -0.0275, -0.0513,
#         -0.0379, -0.0431, -0.0526, -0.0733, -0.0277, -0.0306, -0.0593, -0.0319,
#         -0.0598, -0.0508, -0.0388, -0.0415], device='cuda:0',
#        requires_grad=True)
# Opt step: 18	 Avg reward: 31.08	 std: Parameter containing:
# tensor([-0.0213, -0.0262, -0.0313, -0.0511, -0.0415, -0.0574, -0.0293, -0.0520,
#         -0.0374, -0.0394, -0.0515, -0.0763, -0.0302, -0.0399, -0.0723, -0.0315,
#         -0.0587, -0.0531, -0.0434, -0.0453], device='cuda:0',
#        requires_grad=True)
# Opt step: 19	 Avg reward: 30.51	 std: Parameter containing:
# tensor([-0.0281, -0.0353, -0.0307, -0.0516, -0.0484, -0.0607, -0.0344, -0.0434,
#         -0.0379, -0.0368, -0.0546, -0.0823, -0.0317, -0.0480, -0.0785, -0.0397,
#         -0.0617, -0.0529, -0.0501, -0.0486], device='cuda:0',
#        requires_grad=True)
# Opt step: 20	 Avg reward: 35.75	 std: Parameter containing:
# tensor([-0.0305, -0.0389, -0.0325, -0.0508, -0.0469, -0.0614, -0.0353, -0.0490,
#         -0.0379, -0.0315, -0.0504, -0.0849, -0.0371, -0.0459, -0.0847, -0.0441,
#         -0.0593, -0.0591, -0.0520, -0.0533], device='cuda:0',
#        requires_grad=True)
# Opt step: 21	 Avg reward: 36.68	 std: Parameter containing:
# tensor([-0.0317, -0.0413, -0.0284, -0.0492, -0.0479, -0.0638, -0.0359, -0.0611,
#         -0.0394, -0.0364, -0.0522, -0.0878, -0.0443, -0.0404, -0.0890, -0.0409,
#         -0.0619, -0.0647, -0.0531, -0.0572], device='cuda:0',
#        requires_grad=True)
# Opt step: 22	 Avg reward: 33.52	 std: Parameter containing:
# tensor([-0.0352, -0.0504, -0.0358, -0.0472, -0.0538, -0.0603, -0.0369, -0.0613,
#         -0.0377, -0.0382, -0.0561, -0.0890, -0.0473, -0.0442, -0.0935, -0.0447,
#         -0.0660, -0.0614, -0.0513, -0.0607], device='cuda:0',
#        requires_grad=True)
# Opt step: 23	 Avg reward: 34.20	 std: Parameter containing:
# tensor([-0.0391, -0.0537, -0.0416, -0.0500, -0.0596, -0.0620, -0.0361, -0.0651,
#         -0.0373, -0.0408, -0.0586, -0.0907, -0.0473, -0.0450, -0.0945, -0.0484,
#         -0.0596, -0.0673, -0.0597, -0.0623], device='cuda:0',
#        requires_grad=True)
# Opt step: 24	 Avg reward: 35.12	 std: Parameter containing:
# tensor([-0.0472, -0.0566, -0.0458, -0.0508, -0.0541, -0.0647, -0.0394, -0.0691,
#         -0.0347, -0.0398, -0.0605, -0.0915, -0.0478, -0.0457, -0.0994, -0.0494,
#         -0.0543, -0.0706, -0.0588, -0.0678], device='cuda:0',
#        requires_grad=True)
# Opt step: 25	 Avg reward: 30.80	 std: Parameter containing:
# tensor([-0.0569, -0.0576, -0.0450, -0.0455, -0.0602, -0.0666, -0.0449, -0.0703,
#         -0.0384, -0.0374, -0.0615, -0.0924, -0.0436, -0.0431, -0.1031, -0.0572,
#         -0.0562, -0.0697, -0.0516, -0.0733], device='cuda:0',
#        requires_grad=True)
# Opt step: 26	 Avg reward: 40.14	 std: Parameter containing:
# tensor([-0.0520, -0.0603, -0.0474, -0.0494, -0.0611, -0.0666, -0.0520, -0.0733,
#         -0.0459, -0.0450, -0.0666, -0.0935, -0.0430, -0.0425, -0.1097, -0.0591,
#         -0.0652, -0.0746, -0.0525, -0.0770], device='cuda:0',
#        requires_grad=True)
# Opt step: 27	 Avg reward: 43.35	 std: Parameter containing:
# tensor([-0.0521, -0.0653, -0.0463, -0.0498, -0.0660, -0.0701, -0.0549, -0.0698,
#         -0.0586, -0.0413, -0.0703, -0.1049, -0.0468, -0.0421, -0.1167, -0.0646,
#         -0.0657, -0.0769, -0.0549, -0.0801], device='cuda:0',
#        requires_grad=True)
# Opt step: 28	 Avg reward: 38.80	 std: Parameter containing:
# tensor([-0.0537, -0.0736, -0.0551, -0.0571, -0.0721, -0.0675, -0.0580, -0.0689,
#         -0.0674, -0.0462, -0.0853, -0.1098, -0.0496, -0.0435, -0.1236, -0.0643,
#         -0.0688, -0.0806, -0.0542, -0.0846], device='cuda:0',
#        requires_grad=True)
# Opt step: 29	 Avg reward: 41.28	 std: Parameter containing:
# tensor([-0.0531, -0.0687, -0.0542, -0.0611, -0.0715, -0.0769, -0.0627, -0.0673,
#         -0.0680, -0.0466, -0.0923, -0.1144, -0.0587, -0.0464, -0.1251, -0.0560,
#         -0.0631, -0.0841, -0.0607, -0.0941], device='cuda:0',
#        requires_grad=True)
# Opt step: 30	 Avg reward: 38.56	 std: Parameter containing:
# tensor([-0.0519, -0.0767, -0.0567, -0.0602, -0.0704, -0.0821, -0.0684, -0.0745,
#         -0.0767, -0.0514, -0.0944, -0.1137, -0.0575, -0.0454, -0.1246, -0.0619,
#         -0.0692, -0.0854, -0.0607, -0.0995], device='cuda:0',
#        requires_grad=True)
# Opt step: 31	 Avg reward: 32.39	 std: Parameter containing:
# tensor([-0.0472, -0.0860, -0.0587, -0.0582, -0.0715, -0.0855, -0.0687, -0.0851,
#         -0.0778, -0.0633, -0.0958, -0.1228, -0.0599, -0.0532, -0.1262, -0.0699,
#         -0.0744, -0.0839, -0.0604, -0.1013], device='cuda:0',
#        requires_grad=True)
# Opt step: 32	 Avg reward: 44.22	 std: Parameter containing:
# tensor([-0.0590, -0.0839, -0.0552, -0.0641, -0.0699, -0.0872, -0.0740, -0.0879,
#         -0.0802, -0.0667, -0.1033, -0.1213, -0.0563, -0.0541, -0.1222, -0.0650,
#         -0.0773, -0.0904, -0.0679, -0.0941], device='cuda:0',
#        requires_grad=True)
# Opt step: 33	 Avg reward: 41.12	 std: Parameter containing:
# tensor([-0.0540, -0.0861, -0.0668, -0.0666, -0.0704, -0.0924, -0.0856, -0.0897,
#         -0.0867, -0.0643, -0.1099, -0.1240, -0.0658, -0.0474, -0.1219, -0.0631,
#         -0.0814, -0.0946, -0.0717, -0.0881], device='cuda:0',
#        requires_grad=True)
# Opt step: 34	 Avg reward: 43.69	 std: Parameter containing:
# tensor([-0.0532, -0.0965, -0.0774, -0.0665, -0.0729, -0.0964, -0.0970, -0.0939,
#         -0.0988, -0.0717, -0.1167, -0.1284, -0.0671, -0.0442, -0.1345, -0.0662,
#         -0.0878, -0.1013, -0.0686, -0.0860], device='cuda:0',
#        requires_grad=True)
# Opt step: 35	 Avg reward: 44.07	 std: Parameter containing:
# tensor([-0.0595, -0.0967, -0.0786, -0.0694, -0.0699, -0.1037, -0.1032, -0.0941,
#         -0.1028, -0.0742, -0.1103, -0.1331, -0.0718, -0.0509, -0.1328, -0.0756,
#         -0.0870, -0.1143, -0.0762, -0.0825], device='cuda:0',
#        requires_grad=True)
# Opt step: 36	 Avg reward: 45.09	 std: Parameter containing:
# tensor([-0.0588, -0.1023, -0.0761, -0.0676, -0.0739, -0.1078, -0.1002, -0.0974,
#         -0.1053, -0.0861, -0.1160, -0.1337, -0.0801, -0.0416, -0.1440, -0.0813,
#         -0.0881, -0.1107, -0.0733, -0.0801], device='cuda:0',
#        requires_grad=True)
# Opt step: 37	 Avg reward: 43.92	 std: Parameter containing:
# tensor([-0.0623, -0.1006, -0.0799, -0.0675, -0.0727, -0.1085, -0.1100, -0.0966,
#         -0.1124, -0.0893, -0.1117, -0.1346, -0.0856, -0.0442, -0.1547, -0.0882,
#         -0.0916, -0.1135, -0.0753, -0.0863], device='cuda:0',
#        requires_grad=True)
# Opt step: 38	 Avg reward: 45.13	 std: Parameter containing:
# tensor([-0.0605, -0.1014, -0.0872, -0.0639, -0.0741, -0.1146, -0.1147, -0.1003,
#         -0.1148, -0.0902, -0.1163, -0.1352, -0.0833, -0.0509, -0.1551, -0.0917,
#         -0.0937, -0.1116, -0.0742, -0.0898], device='cuda:0',
#        requires_grad=True)
# Opt step: 39	 Avg reward: 55.78	 std: Parameter containing:
# tensor([-0.0660, -0.1019, -0.0939, -0.0708, -0.0808, -0.1137, -0.1205, -0.1051,
#         -0.1268, -0.0911, -0.1270, -0.1489, -0.0909, -0.0545, -0.1674, -0.0945,
#         -0.1014, -0.1153, -0.0660, -0.0886], device='cuda:0',
#        requires_grad=True)
# Opt step: 40	 Avg reward: 48.80	 std: Parameter containing:
# tensor([-0.0703, -0.1063, -0.1037, -0.0710, -0.0808, -0.1216, -0.1187, -0.1096,
#         -0.1346, -0.0927, -0.1360, -0.1527, -0.0934, -0.0566, -0.1813, -0.0959,
#         -0.1038, -0.1200, -0.0639, -0.0883], device='cuda:0',
#        requires_grad=True)
# Opt step: 41	 Avg reward: 45.27	 std: Parameter containing:
# tensor([-0.0776, -0.1069, -0.1015, -0.0748, -0.0833, -0.1254, -0.1257, -0.1065,
#         -0.1379, -0.1019, -0.1418, -0.1554, -0.0957, -0.0543, -0.1873, -0.0971,
#         -0.1070, -0.1205, -0.0608, -0.0915], device='cuda:0',
#        requires_grad=True)
# Opt step: 42	 Avg reward: 52.06	 std: Parameter containing:
# tensor([-0.0710, -0.1120, -0.1058, -0.0699, -0.0888, -0.1288, -0.1303, -0.1141,
#         -0.1454, -0.1096, -0.1386, -0.1515, -0.0918, -0.0567, -0.1988, -0.1055,
#         -0.1064, -0.1240, -0.0637, -0.0964], device='cuda:0',
#        requires_grad=True)
# Opt step: 43	 Avg reward: 67.45	 std: Parameter containing:
# tensor([-0.0744, -0.1054, -0.1101, -0.0750, -0.0946, -0.1373, -0.1354, -0.1174,
#         -0.1502, -0.1050, -0.1415, -0.1545, -0.0969, -0.0588, -0.2067, -0.1131,
#         -0.1064, -0.1250, -0.0630, -0.0927], device='cuda:0',
#        requires_grad=True)
# Opt step: 44	 Avg reward: 56.21	 std: Parameter containing:
# tensor([-0.0784, -0.1074, -0.1228, -0.0712, -0.0932, -0.1407, -0.1316, -0.1114,
#         -0.1579, -0.1015, -0.1416, -0.1587, -0.0964, -0.0624, -0.2073, -0.1133,
#         -0.1060, -0.1243, -0.0669, -0.0990], device='cuda:0',
#        requires_grad=True)
# Opt step: 45	 Avg reward: 62.36	 std: Parameter containing:
# tensor([-0.0770, -0.1113, -0.1206, -0.0771, -0.0953, -0.1476, -0.1389, -0.1158,
#         -0.1525, -0.1031, -0.1505, -0.1692, -0.1004, -0.0606, -0.2142, -0.1183,
#         -0.1137, -0.1252, -0.0609, -0.1029], device='cuda:0',
#        requires_grad=True)
# Opt step: 46	 Avg reward: 60.32	 std: Parameter containing:
# tensor([-0.0778, -0.1175, -0.1238, -0.0815, -0.0974, -0.1497, -0.1373, -0.1233,
#         -0.1501, -0.1099, -0.1530, -0.1694, -0.1060, -0.0622, -0.2193, -0.1271,
#         -0.1195, -0.1407, -0.0666, -0.1182], device='cuda:0',
#        requires_grad=True)
# Opt step: 47	 Avg reward: 59.09	 std: Parameter containing:
# tensor([-0.0781, -0.1192, -0.1301, -0.0865, -0.0946, -0.1659, -0.1467, -0.1232,
#         -0.1511, -0.1186, -0.1476, -0.1692, -0.1161, -0.0742, -0.2248, -0.1306,
#         -0.1267, -0.1426, -0.0763, -0.1183], device='cuda:0',
#        requires_grad=True)
# Opt step: 48	 Avg reward: 61.16	 std: Parameter containing:
# tensor([-0.0856, -0.1204, -0.1319, -0.0916, -0.0990, -0.1709, -0.1578, -0.1275,
#         -0.1554, -0.1162, -0.1562, -0.1746, -0.1242, -0.0783, -0.2286, -0.1334,
#         -0.1360, -0.1447, -0.0671, -0.1205], device='cuda:0',
#        requires_grad=True)
# Opt step: 49	 Avg reward: 50.02	 std: Parameter containing:
# tensor([-0.0907, -0.1198, -0.1359, -0.1026, -0.1068, -0.1826, -0.1676, -0.1359,
#         -0.1663, -0.1175, -0.1651, -0.1812, -0.1253, -0.0851, -0.2340, -0.1408,
#         -0.1471, -0.1475, -0.0733, -0.1264], device='cuda:0',
#        requires_grad=True)
# Opt step: 50	 Avg reward: 59.08	 std: Parameter containing:
# tensor([-0.1018, -0.1259, -0.1286, -0.1088, -0.1117, -0.1905, -0.1714, -0.1414,
#         -0.1782, -0.1113, -0.1663, -0.1778, -0.1303, -0.0909, -0.2410, -0.1427,
#         -0.1460, -0.1457, -0.0765, -0.1377], device='cuda:0',
#        requires_grad=True)
# Opt step: 51	 Avg reward: 60.99	 std: Parameter containing:
# tensor([-0.1062, -0.1223, -0.1312, -0.1008, -0.1153, -0.1892, -0.1728, -0.1489,
#         -0.1841, -0.1143, -0.1653, -0.1718, -0.1349, -0.1028, -0.2535, -0.1544,
#         -0.1437, -0.1521, -0.0850, -0.1381], device='cuda:0',
#        requires_grad=True)
# Opt step: 52	 Avg reward: 64.06	 std: Parameter containing:
# tensor([-0.1035, -0.1282, -0.1417, -0.1058, -0.1194, -0.1961, -0.1789, -0.1468,
#         -0.1814, -0.1189, -0.1734, -0.1766, -0.1364, -0.1065, -0.2430, -0.1608,
#         -0.1539, -0.1535, -0.0832, -0.1381], device='cuda:0',
#        requires_grad=True)
# Opt step: 53	 Avg reward: 52.55	 std: Parameter containing:
# tensor([-0.1069, -0.1193, -0.1430, -0.1128, -0.1207, -0.1941, -0.1849, -0.1429,
#         -0.1891, -0.1279, -0.1789, -0.1756, -0.1412, -0.1168, -0.2500, -0.1629,
#         -0.1558, -0.1602, -0.0916, -0.1436], device='cuda:0',
#        requires_grad=True)
# Opt step: 54	 Avg reward: 57.95	 std: Parameter containing:
# tensor([-0.1082, -0.1211, -0.1444, -0.1123, -0.1225, -0.2022, -0.1963, -0.1513,
#         -0.1951, -0.1299, -0.1867, -0.1764, -0.1495, -0.1270, -0.2502, -0.1704,
#         -0.1510, -0.1657, -0.0948, -0.1561], device='cuda:0',
#        requires_grad=True)
# Opt step: 55	 Avg reward: 66.38	 std: Parameter containing:
# tensor([-0.1205, -0.1224, -0.1506, -0.1095, -0.1232, -0.2085, -0.1986, -0.1505,
#         -0.1907, -0.1204, -0.1949, -0.1732, -0.1570, -0.1319, -0.2407, -0.1773,
#         -0.1572, -0.1679, -0.0967, -0.1539], device='cuda:0',
#        requires_grad=True)
# Opt step: 56	 Avg reward: 64.63	 std: Parameter containing:
# tensor([-0.1250, -0.1252, -0.1626, -0.1127, -0.1258, -0.2047, -0.2001, -0.1644,
#         -0.1851, -0.1327, -0.1960, -0.1793, -0.1635, -0.1288, -0.2498, -0.1870,
#         -0.1681, -0.1586, -0.0912, -0.1637], device='cuda:0',
#        requires_grad=True)
# Opt step: 57	 Avg reward: 66.53	 std: Parameter containing:
# tensor([-0.1192, -0.1283, -0.1691, -0.1225, -0.1337, -0.2016, -0.2114, -0.1663,
#         -0.1936, -0.1375, -0.2038, -0.1787, -0.1660, -0.1380, -0.2507, -0.1887,
#         -0.1681, -0.1539, -0.0989, -0.1740], device='cuda:0',
#        requires_grad=True)
# Opt step: 58	 Avg reward: 70.97	 std: Parameter containing:
# tensor([-0.1215, -0.1408, -0.1665, -0.1266, -0.1294, -0.2015, -0.2190, -0.1753,
#         -0.2036, -0.1438, -0.2022, -0.1950, -0.1652, -0.1388, -0.2450, -0.1991,
#         -0.1717, -0.1641, -0.1100, -0.1761], device='cuda:0',
#        requires_grad=True)
# Opt step: 59	 Avg reward: 64.61	 std: Parameter containing:
# tensor([-0.1245, -0.1371, -0.1740, -0.1308, -0.1370, -0.2043, -0.2267, -0.1745,
#         -0.1967, -0.1465, -0.2094, -0.2008, -0.1644, -0.1398, -0.2371, -0.2042,
#         -0.1712, -0.1690, -0.1197, -0.1802], device='cuda:0',
#        requires_grad=True)
# Opt step: 60	 Avg reward: 66.60	 std: Parameter containing:
# tensor([-0.1304, -0.1488, -0.1753, -0.1418, -0.1407, -0.2122, -0.2304, -0.1821,
#         -0.2022, -0.1541, -0.2130, -0.1951, -0.1660, -0.1549, -0.2447, -0.2126,
#         -0.1757, -0.1740, -0.1194, -0.1849], device='cuda:0',
#        requires_grad=True)
# Opt step: 61	 Avg reward: 73.13	 std: Parameter containing:
# tensor([-0.1275, -0.1474, -0.1739, -0.1481, -0.1532, -0.2058, -0.2332, -0.1844,
#         -0.2056, -0.1551, -0.2150, -0.1940, -0.1715, -0.1698, -0.2455, -0.2200,
#         -0.1839, -0.1840, -0.1290, -0.1870], device='cuda:0',
#        requires_grad=True)
# Opt step: 62	 Avg reward: 75.72	 std: Parameter containing:
# tensor([-0.1323, -0.1479, -0.1657, -0.1502, -0.1525, -0.2093, -0.2446, -0.1868,
#         -0.2094, -0.1603, -0.2215, -0.1915, -0.1792, -0.1740, -0.2359, -0.2175,
#         -0.1895, -0.1837, -0.1302, -0.2067], device='cuda:0',
#        requires_grad=True)
# Opt step: 63	 Avg reward: 70.85	 std: Parameter containing:
# tensor([-0.1507, -0.1536, -0.1654, -0.1557, -0.1658, -0.1994, -0.2519, -0.1872,
#         -0.2207, -0.1707, -0.2244, -0.1978, -0.1786, -0.1839, -0.2402, -0.2182,
#         -0.1928, -0.1798, -0.1246, -0.2089], device='cuda:0',
#        requires_grad=True)
# Opt step: 64	 Avg reward: 83.85	 std: Parameter containing:
# tensor([-0.1495, -0.1578, -0.1675, -0.1502, -0.1645, -0.2000, -0.2588, -0.1873,
#         -0.2296, -0.1760, -0.2335, -0.2040, -0.1716, -0.1850, -0.2442, -0.2183,
#         -0.1875, -0.1768, -0.1238, -0.2109], device='cuda:0',
#        requires_grad=True)
# Opt step: 65	 Avg reward: 76.99	 std: Parameter containing:
# tensor([-0.1500, -0.1647, -0.1759, -0.1584, -0.1774, -0.2043, -0.2587, -0.1887,
#         -0.2296, -0.1833, -0.2340, -0.2011, -0.1771, -0.1808, -0.2572, -0.2137,
#         -0.1909, -0.1858, -0.1228, -0.2176], device='cuda:0',
#        requires_grad=True)
# Opt step: 66	 Avg reward: -98.08	 std: Parameter containing:
# tensor([-0.1470, -0.1406, -0.1531, -0.1527, -0.1683, -0.2029, -0.2385, -0.1752,
#         -0.2167, -0.1754, -0.2233, -0.1715, -0.1666, -0.1680, -0.2432, -0.2057,
#         -0.1816, -0.1666, -0.1032, -0.1960], device='cuda:0',
#        requires_grad=True)
# Opt step: 67	 Avg reward: 65.27	 std: Parameter containing:
# tensor([-0.1494, -0.1408, -0.1564, -0.1442, -0.1671, -0.2052, -0.2523, -0.1777,
#         -0.2155, -0.1825, -0.2184, -0.1727, -0.1631, -0.1668, -0.2550, -0.2035,
#         -0.1768, -0.1628, -0.0928, -0.1982], device='cuda:0',
#        requires_grad=True)
# Opt step: 68	 Avg reward: 63.44	 std: Parameter containing:
# tensor([-0.1521, -0.1409, -0.1569, -0.1396, -0.1678, -0.2119, -0.2543, -0.1815,
#         -0.2116, -0.1775, -0.2259, -0.1720, -0.1653, -0.1815, -0.2710, -0.1993,
#         -0.1807, -0.1714, -0.0986, -0.1947], device='cuda:0',
#        requires_grad=True)
# Opt step: 69	 Avg reward: 53.67	 std: Parameter containing:
# tensor([-0.1502, -0.1438, -0.1629, -0.1485, -0.1752, -0.2187, -0.2533, -0.1879,
#         -0.2125, -0.1959, -0.2256, -0.1773, -0.1685, -0.1866, -0.2697, -0.2047,
#         -0.1741, -0.1701, -0.0999, -0.1994], device='cuda:0',
#        requires_grad=True)
# Opt step: 70	 Avg reward: 67.77	 std: Parameter containing:
# tensor([-0.1496, -0.1469, -0.1713, -0.1425, -0.1825, -0.2208, -0.2629, -0.1868,
#         -0.2190, -0.1933, -0.2142, -0.1818, -0.1700, -0.1982, -0.2697, -0.2125,
#         -0.1781, -0.1609, -0.1016, -0.2018], device='cuda:0',
#        requires_grad=True)
# Opt step: 71	 Avg reward: 78.79	 std: Parameter containing:
# tensor([-0.1509, -0.1514, -0.1787, -0.1488, -0.1876, -0.2221, -0.2655, -0.1827,
#         -0.2149, -0.2043, -0.2146, -0.1816, -0.1737, -0.1971, -0.2681, -0.2204,
#         -0.1871, -0.1643, -0.1076, -0.1998], device='cuda:0',
#        requires_grad=True)
# Opt step: 72	 Avg reward: 73.58	 std: Parameter containing:
# tensor([-0.1573, -0.1568, -0.1964, -0.1477, -0.2003, -0.2215, -0.2693, -0.1864,
#         -0.2185, -0.2062, -0.2144, -0.1889, -0.1704, -0.2028, -0.2736, -0.2138,
#         -0.1990, -0.1673, -0.1078, -0.2029], device='cuda:0',
#        requires_grad=True)
# Opt step: 73	 Avg reward: 65.29	 std: Parameter containing:
# tensor([-0.1577, -0.1607, -0.2061, -0.1565, -0.1953, -0.2261, -0.2683, -0.1824,
#         -0.2226, -0.2106, -0.2031, -0.1880, -0.1834, -0.1963, -0.2713, -0.2195,
#         -0.1935, -0.1718, -0.1090, -0.2016], device='cuda:0',
#        requires_grad=True)
# Opt step: 74	 Avg reward: 65.50	 std: Parameter containing:
# tensor([-0.1681, -0.1592, -0.2102, -0.1605, -0.2032, -0.2317, -0.2703, -0.1758,
#         -0.2208, -0.2205, -0.2037, -0.1916, -0.1833, -0.1974, -0.2690, -0.2208,
#         -0.2040, -0.1762, -0.1069, -0.2072], device='cuda:0',
#        requires_grad=True)
# Opt step: 75	 Avg reward: 68.26	 std: Parameter containing:
# tensor([-0.1691, -0.1599, -0.2218, -0.1594, -0.2015, -0.2352, -0.2668, -0.1805,
#         -0.2234, -0.2297, -0.2090, -0.1885, -0.1807, -0.2094, -0.2699, -0.2275,
#         -0.2173, -0.1746, -0.1165, -0.2083], device='cuda:0',
#        requires_grad=True)
# Opt step: 76	 Avg reward: 58.81	 std: Parameter containing:
# tensor([-0.1691, -0.1591, -0.2279, -0.1655, -0.2075, -0.2247, -0.2713, -0.1982,
#         -0.2302, -0.2326, -0.2145, -0.1904, -0.1824, -0.2088, -0.2768, -0.2341,
#         -0.2251, -0.1682, -0.1115, -0.2118], device='cuda:0',
#        requires_grad=True)
# Opt step: 77	 Avg reward: 61.01	 std: Parameter containing:
# tensor([-0.1734, -0.1630, -0.2347, -0.1640, -0.2054, -0.2290, -0.2794, -0.1906,
#         -0.2363, -0.2368, -0.2177, -0.1943, -0.1817, -0.2156, -0.2858, -0.2347,
#         -0.2279, -0.1701, -0.1142, -0.2166], device='cuda:0',
#        requires_grad=True)
# Opt step: 78	 Avg reward: 58.05	 std: Parameter containing:
# tensor([-0.1770, -0.1651, -0.2326, -0.1725, -0.2130, -0.2341, -0.2721, -0.1895,
#         -0.2437, -0.2390, -0.2173, -0.2014, -0.1846, -0.2240, -0.2898, -0.2384,
#         -0.2248, -0.1711, -0.1223, -0.2147], device='cuda:0',
#        requires_grad=True)
# Opt step: 79	 Avg reward: -214.13	 std: Parameter containing:
# tensor([-0.1749, -0.1692, -0.2376, -0.1818, -0.2210, -0.2409, -0.2716, -0.1909,
#         -0.2426, -0.2467, -0.2165, -0.2085, -0.1932, -0.2302, -0.2901, -0.2488,
#         -0.2232, -0.1802, -0.1322, -0.2120], device='cuda:0',
#        requires_grad=True)
# Opt step: 80	 Avg reward: 62.38	 std: Parameter containing:
# tensor([-0.1802, -0.1784, -0.2368, -0.1775, -0.2133, -0.2465, -0.2753, -0.2063,
#         -0.2481, -0.2589, -0.2013, -0.2213, -0.1939, -0.2343, -0.2881, -0.2503,
#         -0.2248, -0.1872, -0.1230, -0.2180], device='cuda:0',
#        requires_grad=True)
# Opt step: 81	 Avg reward: 70.92	 std: Parameter containing:
# tensor([-0.1804, -0.1745, -0.2276, -0.1683, -0.2172, -0.2432, -0.2830, -0.2159,
#         -0.2539, -0.2616, -0.2034, -0.2388, -0.1988, -0.2294, -0.2935, -0.2523,
#         -0.2150, -0.1911, -0.1373, -0.2220], device='cuda:0',
#        requires_grad=True)
# Opt step: 82	 Avg reward: 63.82	 std: Parameter containing:
# tensor([-0.1829, -0.1756, -0.2302, -0.1683, -0.2147, -0.2459, -0.2856, -0.2211,
#         -0.2584, -0.2598, -0.2074, -0.2468, -0.2068, -0.2265, -0.2992, -0.2529,
#         -0.2161, -0.1798, -0.1387, -0.2162], device='cuda:0',
#        requires_grad=True)
# Opt step: 83	 Avg reward: 79.52	 std: Parameter containing:
# tensor([-0.1877, -0.1674, -0.2306, -0.1641, -0.2179, -0.2487, -0.2952, -0.2244,
#         -0.2618, -0.2596, -0.2106, -0.2523, -0.2176, -0.2230, -0.3071, -0.2464,
#         -0.2073, -0.1876, -0.1375, -0.2201], device='cuda:0',
#        requires_grad=True)
# Opt step: 84	 Avg reward: 87.73	 std: Parameter containing:
# tensor([-0.1891, -0.1712, -0.2312, -0.1667, -0.2149, -0.2536, -0.3019, -0.2268,
#         -0.2702, -0.2621, -0.2079, -0.2555, -0.2247, -0.2330, -0.3229, -0.2508,
#         -0.2134, -0.1711, -0.1399, -0.2232], device='cuda:0',
#        requires_grad=True)
# Opt step: 85	 Avg reward: 71.24	 std: Parameter containing:
# tensor([-0.1938, -0.1752, -0.2328, -0.1711, -0.2132, -0.2537, -0.3069, -0.2303,
#         -0.2795, -0.2650, -0.2140, -0.2483, -0.2240, -0.2308, -0.3296, -0.2533,
#         -0.2130, -0.1713, -0.1395, -0.2266], device='cuda:0',
#        requires_grad=True)
# Opt step: 86	 Avg reward: 74.10	 std: Parameter containing:
# tensor([-0.1925, -0.1770, -0.2327, -0.1656, -0.2101, -0.2511, -0.2994, -0.2452,
#         -0.2903, -0.2629, -0.2174, -0.2523, -0.2190, -0.2305, -0.3457, -0.2428,
#         -0.2056, -0.1789, -0.1473, -0.2261], device='cuda:0',
#        requires_grad=True)
# Opt step: 87	 Avg reward: 82.46	 std: Parameter containing:
# tensor([-0.1842, -0.1635, -0.2255, -0.1707, -0.1988, -0.2473, -0.2892, -0.2367,
#         -0.2772, -0.2521, -0.2080, -0.2408, -0.2108, -0.2180, -0.3442, -0.2275,
#         -0.2030, -0.1703, -0.1341, -0.2195], device='cuda:0',
#        requires_grad=True)
# Opt step: 88	 Avg reward: 72.27	 std: Parameter containing:
# tensor([-0.1806, -0.1522, -0.2260, -0.1670, -0.2012, -0.2500, -0.2860, -0.2387,
#         -0.2794, -0.2407, -0.2164, -0.2409, -0.2165, -0.2351, -0.3384, -0.2254,
#         -0.1982, -0.1807, -0.1356, -0.2126], device='cuda:0',
#        requires_grad=True)
# Opt step: 89	 Avg reward: 70.44	 std: Parameter containing:
# tensor([-0.1897, -0.1505, -0.2299, -0.1675, -0.2113, -0.2433, -0.2689, -0.2379,
#         -0.2851, -0.2513, -0.2210, -0.2377, -0.2327, -0.2388, -0.3281, -0.2258,
#         -0.2046, -0.1887, -0.1320, -0.2169], device='cuda:0',
#        requires_grad=True)
# Opt step: 90	 Avg reward: 66.19	 std: Parameter containing:
# tensor([-0.1838, -0.1573, -0.2446, -0.1677, -0.2156, -0.2535, -0.2602, -0.2428,
#         -0.2846, -0.2586, -0.2226, -0.2344, -0.2311, -0.2513, -0.3282, -0.2326,
#         -0.1986, -0.1888, -0.1395, -0.2195], device='cuda:0',
#        requires_grad=True)
# Opt step: 91	 Avg reward: 73.29	 std: Parameter containing:
# tensor([-0.1801, -0.1564, -0.2450, -0.1676, -0.2190, -0.2542, -0.2548, -0.2473,
#         -0.2908, -0.2573, -0.2258, -0.2347, -0.2436, -0.2570, -0.3223, -0.2325,
#         -0.2018, -0.1944, -0.1413, -0.2223], device='cuda:0',
#        requires_grad=True)
# Opt step: 92	 Avg reward: 77.41	 std: Parameter containing:
# tensor([-0.1822, -0.1547, -0.2521, -0.1718, -0.2225, -0.2584, -0.2502, -0.2463,
#         -0.2966, -0.2583, -0.2172, -0.2385, -0.2520, -0.2654, -0.3108, -0.2417,
#         -0.1989, -0.2042, -0.1440, -0.2206], device='cuda:0',
#        requires_grad=True)
# Opt step: 93	 Avg reward: 88.84	 std: Parameter containing:
# tensor([-0.1902, -0.1675, -0.2432, -0.1556, -0.2144, -0.2640, -0.2594, -0.2485,
#         -0.2890, -0.2568, -0.2248, -0.2395, -0.2487, -0.2688, -0.3156, -0.2491,
#         -0.2020, -0.2058, -0.1476, -0.2161], device='cuda:0',
#        requires_grad=True)
# Opt step: 94	 Avg reward: 77.50	 std: Parameter containing:
# tensor([-0.1950, -0.1722, -0.2345, -0.1568, -0.2190, -0.2628, -0.2578, -0.2475,
#         -0.2896, -0.2554, -0.2169, -0.2298, -0.2400, -0.2728, -0.3207, -0.2534,
#         -0.1991, -0.2099, -0.1554, -0.2100], device='cuda:0',
#        requires_grad=True)
# Opt step: 95	 Avg reward: 76.99	 std: Parameter containing:
# tensor([-0.1951, -0.1634, -0.2371, -0.1636, -0.2268, -0.2678, -0.2502, -0.2422,
#         -0.2991, -0.2613, -0.2150, -0.2219, -0.2450, -0.2724, -0.3284, -0.2571,
#         -0.2060, -0.2217, -0.1595, -0.2049], device='cuda:0',
#        requires_grad=True)
# Opt step: 96	 Avg reward: 84.16	 std: Parameter containing:
# tensor([-0.2059, -0.1662, -0.2372, -0.1725, -0.2285, -0.2674, -0.2525, -0.2255,
#         -0.3020, -0.2774, -0.2112, -0.2283, -0.2359, -0.2705, -0.3342, -0.2515,
#         -0.1991, -0.2144, -0.1713, -0.2061], device='cuda:0',
#        requires_grad=True)
# Opt step: 97	 Avg reward: 77.71	 std: Parameter containing:
# tensor([-0.2141, -0.1659, -0.2428, -0.1723, -0.2304, -0.2668, -0.2592, -0.2345,
#         -0.3149, -0.2762, -0.2157, -0.2248, -0.2298, -0.2779, -0.3123, -0.2534,
#         -0.1983, -0.2226, -0.1905, -0.2118], device='cuda:0',
#        requires_grad=True)
# Opt step: 98	 Avg reward: 93.65	 std: Parameter containing:
# tensor([-0.2185, -0.1748, -0.2478, -0.1767, -0.2349, -0.2617, -0.2587, -0.2324,
#         -0.3107, -0.2799, -0.2187, -0.2334, -0.2274, -0.2631, -0.3151, -0.2629,
#         -0.1925, -0.2263, -0.1780, -0.2179], device='cuda:0',
#        requires_grad=True)
# Opt step: 99	 Avg reward: 92.19	 std: Parameter containing:
# tensor([-0.2207, -0.1822, -0.2540, -0.1633, -0.2385, -0.2688, -0.2684, -0.2328,
#         -0.3143, -0.2847, -0.2220, -0.2364, -0.2290, -0.2649, -0.3107, -0.2695,
#         -0.2006, -0.2241, -0.1743, -0.2244], device='cuda:0',
#        requires_grad=True)
# Opt step: 100	 Avg reward: 95.49	 std: Parameter containing:
# tensor([-0.2317, -0.1827, -0.2472, -0.1621, -0.2394, -0.2640, -0.2701, -0.2372,
#         -0.3130, -0.2811, -0.2224, -0.2351, -0.2237, -0.2666, -0.3143, -0.2714,
#         -0.2010, -0.2315, -0.1762, -0.2270], device='cuda:0',
#        requires_grad=True)
# Opt step: 101	 Avg reward: 95.49	 std: Parameter containing:
# tensor([-0.2259, -0.1851, -0.2510, -0.1571, -0.2429, -0.2529, -0.2788, -0.2256,
#         -0.3166, -0.2828, -0.2291, -0.2248, -0.2314, -0.2732, -0.3171, -0.2699,
#         -0.2078, -0.2312, -0.1855, -0.2317], device='cuda:0',
#        requires_grad=True)
# Opt step: 102	 Avg reward: 93.82	 std: Parameter containing:
# tensor([-0.2345, -0.1795, -0.2543, -0.1577, -0.2416, -0.2418, -0.2897, -0.2215,
#         -0.3121, -0.2930, -0.2240, -0.2291, -0.2341, -0.2768, -0.3210, -0.2682,
#         -0.2072, -0.2377, -0.1939, -0.2415], device='cuda:0',
#        requires_grad=True)
# Opt step: 103	 Avg reward: 89.91	 std: Parameter containing:
# tensor([-0.2318, -0.1769, -0.2587, -0.1630, -0.2514, -0.2400, -0.2849, -0.2244,
#         -0.3153, -0.2932, -0.2147, -0.2370, -0.2367, -0.2737, -0.3197, -0.2621,
#         -0.2045, -0.2355, -0.1899, -0.2480], device='cuda:0',
#        requires_grad=True)
# Opt step: 104	 Avg reward: 100.72	 std: Parameter containing:
# tensor([-0.2350, -0.1766, -0.2636, -0.1571, -0.2580, -0.2385, -0.2895, -0.2218,
#         -0.3203, -0.2954, -0.2200, -0.2385, -0.2420, -0.2798, -0.3223, -0.2593,
#         -0.2125, -0.2319, -0.1960, -0.2481], device='cuda:0',
#        requires_grad=True)
# Opt step: 105	 Avg reward: 95.07	 std: Parameter containing:
# tensor([-0.2366, -0.1912, -0.2606, -0.1539, -0.2548, -0.2508, -0.2895, -0.2170,
#         -0.3305, -0.2878, -0.2234, -0.2350, -0.2401, -0.2811, -0.3216, -0.2649,
#         -0.2060, -0.2439, -0.1934, -0.2530], device='cuda:0',
#        requires_grad=True)
# Opt step: 106	 Avg reward: 94.06	 std: Parameter containing:
# tensor([-0.2471, -0.1936, -0.2659, -0.1570, -0.2590, -0.2503, -0.2843, -0.2279,
#         -0.3281, -0.2900, -0.2135, -0.2377, -0.2535, -0.2868, -0.3150, -0.2610,
#         -0.2080, -0.2412, -0.1952, -0.2616], device='cuda:0',
#        requires_grad=True)
# Opt step: 107	 Avg reward: 97.03	 std: Parameter containing:
# tensor([-0.2440, -0.1902, -0.2639, -0.1678, -0.2624, -0.2567, -0.2958, -0.2253,
#         -0.3363, -0.2915, -0.2154, -0.2381, -0.2704, -0.2847, -0.3142, -0.2738,
#         -0.2025, -0.2419, -0.1907, -0.2659], device='cuda:0',
#        requires_grad=True)
# Opt step: 108	 Avg reward: 90.10	 std: Parameter containing:
# tensor([-0.2465, -0.1926, -0.2744, -0.1602, -0.2590, -0.2604, -0.3017, -0.2216,
#         -0.3436, -0.2952, -0.2293, -0.2536, -0.2675, -0.2852, -0.3164, -0.2789,
#         -0.2046, -0.2402, -0.1870, -0.2685], device='cuda:0',
#        requires_grad=True)
# Opt step: 109	 Avg reward: 93.61	 std: Parameter containing:
# tensor([-0.2431, -0.1861, -0.2758, -0.1673, -0.2657, -0.2453, -0.3095, -0.2147,
#         -0.3470, -0.3014, -0.2245, -0.2468, -0.2683, -0.2778, -0.3239, -0.2821,
#         -0.2053, -0.2355, -0.1909, -0.2625], device='cuda:0',
#        requires_grad=True)
# Opt step: 110	 Avg reward: 104.28	 std: Parameter containing:
# tensor([-0.2619, -0.1914, -0.2714, -0.1693, -0.2788, -0.2396, -0.3004, -0.2283,
#         -0.3338, -0.2966, -0.2242, -0.2341, -0.2702, -0.2801, -0.3199, -0.2893,
#         -0.2036, -0.2308, -0.1903, -0.2656], device='cuda:0',
#        requires_grad=True)
# Opt step: 111	 Avg reward: 95.00	 std: Parameter containing:
# tensor([-0.2598, -0.1822, -0.2702, -0.1731, -0.2816, -0.2499, -0.3011, -0.2194,
#         -0.3375, -0.3060, -0.2306, -0.2301, -0.2743, -0.2744, -0.3105, -0.2855,
#         -0.2059, -0.2380, -0.1857, -0.2723], device='cuda:0',
#        requires_grad=True)
# Opt step: 112	 Avg reward: 92.45	 std: Parameter containing:
# tensor([-0.2621, -0.1776, -0.2812, -0.1708, -0.2798, -0.2485, -0.3079, -0.2161,
#         -0.3274, -0.3065, -0.2275, -0.2294, -0.2799, -0.2868, -0.3048, -0.2857,
#         -0.2075, -0.2384, -0.1805, -0.2710], device='cuda:0',
#        requires_grad=True)
# Opt step: 113	 Avg reward: 88.07	 std: Parameter containing:
# tensor([-0.2559, -0.1726, -0.2842, -0.1662, -0.2746, -0.2333, -0.3052, -0.2242,
#         -0.3276, -0.3122, -0.2284, -0.2299, -0.2848, -0.2831, -0.3152, -0.2954,
#         -0.2091, -0.2213, -0.1768, -0.2797], device='cuda:0',
#        requires_grad=True)
# Opt step: 114	 Avg reward: 97.78	 std: Parameter containing:
# tensor([-0.2621, -0.1715, -0.2895, -0.1740, -0.2704, -0.2316, -0.3103, -0.2247,
#         -0.3257, -0.3189, -0.2428, -0.2243, -0.2829, -0.2769, -0.3195, -0.2999,
#         -0.2022, -0.2313, -0.1657, -0.2889], device='cuda:0',
#        requires_grad=True)
# Opt step: 115	 Avg reward: 90.08	 std: Parameter containing:
# tensor([-0.2583, -0.1714, -0.2897, -0.1755, -0.2759, -0.2392, -0.3176, -0.2135,
#         -0.3203, -0.3180, -0.2491, -0.2321, -0.2768, -0.2803, -0.3315, -0.3173,
#         -0.2114, -0.2371, -0.1643, -0.2865], device='cuda:0',
#        requires_grad=True)
# Opt step: 116	 Avg reward: 92.65	 std: Parameter containing:
# tensor([-0.2574, -0.1751, -0.2884, -0.1785, -0.2871, -0.2379, -0.3163, -0.2079,
#         -0.3382, -0.3257, -0.2572, -0.2396, -0.2802, -0.2888, -0.3423, -0.3234,
#         -0.2184, -0.2513, -0.1626, -0.2851], device='cuda:0',
#        requires_grad=True)
# Opt step: 117	 Avg reward: 97.45	 std: Parameter containing:
# tensor([-0.2648, -0.1690, -0.2974, -0.1751, -0.2910, -0.2406, -0.3329, -0.2009,
#         -0.3385, -0.3269, -0.2618, -0.2445, -0.2727, -0.2841, -0.3464, -0.3322,
#         -0.2107, -0.2500, -0.1597, -0.2880], device='cuda:0',
#        requires_grad=True)
# Opt step: 118	 Avg reward: 102.43	 std: Parameter containing:
# tensor([-0.2633, -0.1623, -0.2995, -0.1838, -0.2999, -0.2395, -0.3263, -0.1989,
#         -0.3465, -0.3251, -0.2534, -0.2471, -0.2745, -0.2874, -0.3376, -0.3383,
#         -0.2105, -0.2401, -0.1574, -0.2899], device='cuda:0',
#        requires_grad=True)
# Opt step: 119	 Avg reward: 93.67	 std: Parameter containing:
# tensor([-0.2627, -0.1731, -0.2996, -0.1838, -0.3032, -0.2474, -0.3218, -0.1973,
#         -0.3569, -0.3262, -0.2677, -0.2505, -0.2646, -0.2871, -0.3361, -0.3399,
#         -0.2045, -0.2438, -0.1509, -0.2866], device='cuda:0',
#        requires_grad=True)
# Opt step: 120	 Avg reward: 113.94	 std: Parameter containing:
# tensor([-0.2703, -0.1691, -0.3016, -0.1714, -0.3114, -0.2438, -0.3207, -0.1968,
#         -0.3495, -0.3357, -0.2673, -0.2439, -0.2676, -0.2838, -0.3453, -0.3377,
#         -0.2101, -0.2414, -0.1382, -0.2999], device='cuda:0',
#        requires_grad=True)
# Opt step: 121	 Avg reward: 111.56	 std: Parameter containing:
# tensor([-0.2691, -0.1665, -0.3022, -0.1925, -0.3189, -0.2485, -0.3240, -0.1915,
#         -0.3496, -0.3343, -0.2666, -0.2523, -0.2720, -0.2884, -0.3464, -0.3405,
#         -0.2126, -0.2419, -0.1302, -0.2965], device='cuda:0',
#        requires_grad=True)
# Opt step: 122	 Avg reward: 102.18	 std: Parameter containing:
# tensor([-0.2730, -0.1715, -0.2982, -0.2014, -0.3120, -0.2449, -0.3338, -0.1860,
#         -0.3515, -0.3302, -0.2632, -0.2413, -0.2690, -0.2905, -0.3551, -0.3419,
#         -0.2090, -0.2500, -0.1255, -0.3051], device='cuda:0',
#        requires_grad=True)
# Opt step: 123	 Avg reward: 101.10	 std: Parameter containing:
# tensor([-0.2798, -0.1809, -0.3056, -0.2094, -0.3103, -0.2263, -0.3332, -0.1879,
#         -0.3491, -0.3440, -0.2630, -0.2423, -0.2717, -0.2862, -0.3505, -0.3405,
#         -0.2272, -0.2453, -0.1319, -0.3027], device='cuda:0',
#        requires_grad=True)
# Opt step: 124	 Avg reward: 112.25	 std: Parameter containing:
# tensor([-0.2834, -0.1802, -0.3122, -0.2110, -0.3267, -0.2256, -0.3403, -0.1931,
#         -0.3461, -0.3380, -0.2636, -0.2443, -0.2777, -0.2884, -0.3474, -0.3421,
#         -0.2255, -0.2387, -0.1388, -0.3021], device='cuda:0',
#        requires_grad=True)
# Opt step: 125	 Avg reward: 109.55	 std: Parameter containing:
# tensor([-0.2796, -0.1677, -0.3218, -0.2035, -0.3326, -0.2250, -0.3432, -0.1877,
#         -0.3383, -0.3483, -0.2739, -0.2571, -0.2729, -0.3009, -0.3498, -0.3372,
#         -0.2241, -0.2452, -0.1449, -0.3000], device='cuda:0',
#        requires_grad=True)
# Opt step: 126	 Avg reward: 107.78	 std: Parameter containing:
# tensor([-0.2749, -0.1797, -0.3314, -0.1998, -0.3349, -0.2327, -0.3440, -0.1844,
#         -0.3360, -0.3409, -0.2777, -0.2603, -0.2673, -0.3004, -0.3474, -0.3395,
#         -0.2193, -0.2366, -0.1421, -0.3040], device='cuda:0',
#        requires_grad=True)
# Opt step: 127	 Avg reward: 113.21	 std: Parameter containing:
# tensor([-0.2710, -0.1850, -0.3341, -0.2133, -0.3371, -0.2308, -0.3461, -0.1844,
#         -0.3369, -0.3433, -0.2884, -0.2597, -0.2766, -0.3007, -0.3451, -0.3399,
#         -0.2211, -0.2318, -0.1450, -0.3150], device='cuda:0',
#        requires_grad=True)
# Opt step: 128	 Avg reward: 129.48	 std: Parameter containing:
# tensor([-0.2809, -0.1972, -0.3350, -0.2163, -0.3368, -0.2292, -0.3503, -0.1874,
#         -0.3335, -0.3462, -0.2812, -0.2659, -0.2803, -0.3006, -0.3471, -0.3342,
#         -0.2175, -0.2388, -0.1483, -0.3149], device='cuda:0',
#        requires_grad=True)
# Opt step: 129	 Avg reward: 102.31	 std: Parameter containing:
# tensor([-0.2869, -0.2071, -0.3308, -0.2149, -0.3269, -0.2253, -0.3588, -0.1812,
#         -0.3271, -0.3499, -0.2786, -0.2723, -0.2758, -0.3114, -0.3511, -0.3323,
#         -0.2107, -0.2536, -0.1591, -0.3159], device='cuda:0',
#        requires_grad=True)
# Opt step: 130	 Avg reward: 119.42	 std: Parameter containing:
# tensor([-0.2855, -0.2141, -0.3276, -0.2146, -0.3358, -0.2336, -0.3605, -0.1865,
#         -0.3344, -0.3491, -0.2741, -0.2668, -0.2741, -0.3197, -0.3585, -0.3331,
#         -0.2112, -0.2500, -0.1575, -0.3194], device='cuda:0',
#        requires_grad=True)
# Opt step: 131	 Avg reward: 98.19	 std: Parameter containing:
# tensor([-0.2839, -0.2109, -0.3235, -0.2227, -0.3258, -0.2255, -0.3635, -0.1900,
#         -0.3392, -0.3569, -0.2726, -0.2733, -0.2710, -0.3221, -0.3642, -0.3389,
#         -0.2072, -0.2509, -0.1649, -0.3258], device='cuda:0',
#        requires_grad=True)
# Opt step: 132	 Avg reward: -99.21	 std: Parameter containing:
# tensor([-0.2861, -0.2176, -0.3259, -0.2122, -0.3288, -0.2317, -0.3730, -0.1921,
#         -0.3509, -0.3694, -0.2741, -0.2715, -0.2768, -0.3202, -0.3651, -0.3445,
#         -0.2175, -0.2515, -0.1691, -0.3292], device='cuda:0',
#        requires_grad=True)
# Opt step: 133	 Avg reward: 108.48	 std: Parameter containing:
# tensor([-0.2933, -0.2159, -0.3337, -0.2082, -0.3258, -0.2226, -0.3753, -0.1903,
#         -0.3586, -0.3736, -0.2769, -0.2813, -0.2711, -0.3171, -0.3541, -0.3557,
#         -0.2167, -0.2565, -0.1645, -0.3247], device='cuda:0',
#        requires_grad=True)
# Opt step: 134	 Avg reward: 125.22	 std: Parameter containing:
# tensor([-0.2919, -0.2205, -0.3320, -0.2033, -0.3238, -0.2176, -0.3912, -0.1952,
#         -0.3573, -0.3776, -0.2708, -0.2859, -0.2833, -0.3214, -0.3521, -0.3530,
#         -0.2066, -0.2541, -0.1644, -0.3345], device='cuda:0',
#        requires_grad=True)
# Opt step: 135	 Avg reward: 113.95	 std: Parameter containing:
# tensor([-0.2943, -0.2259, -0.3207, -0.2020, -0.3317, -0.2132, -0.3832, -0.1946,
#         -0.3689, -0.3708, -0.2721, -0.2891, -0.2729, -0.3249, -0.3627, -0.3617,
#         -0.2042, -0.2463, -0.1657, -0.3347], device='cuda:0',
#        requires_grad=True)
# Opt step: 136	 Avg reward: 114.02	 std: Parameter containing:
# tensor([-0.2966, -0.2231, -0.3194, -0.2028, -0.3354, -0.2073, -0.3865, -0.1945,
#         -0.3699, -0.3679, -0.2777, -0.2862, -0.2693, -0.3179, -0.3737, -0.3619,
#         -0.2107, -0.2465, -0.1730, -0.3342], device='cuda:0',
#        requires_grad=True)
# Opt step: 141	 Avg reward: 130.50	 std: Parameter containing:
# tensor([-0.3117, -0.2219, -0.3417, -0.2141, -0.3223, -0.2412, -0.3966, -0.1708,
#         -0.3797, -0.3965, -0.2842, -0.3108, -0.2892, -0.3067, -0.3787, -0.3612,
#         -0.2351, -0.2416, -0.1768, -0.3208], device='cuda:0',
#        requires_grad=True)
# Opt step: 142	 Avg reward: 129.09	 std: Parameter containing:
# tensor([-0.3102, -0.2305, -0.3306, -0.2073, -0.3219, -0.2332, -0.4094, -0.1635,
#         -0.3840, -0.3919, -0.2918, -0.3195, -0.2889, -0.3113, -0.3759, -0.3702,
#         -0.2426, -0.2539, -0.1719, -0.3255], device='cuda:0',
#        requires_grad=True)
# Opt step: 143	 Avg reward: 124.34	 std: Parameter containing:
# tensor([-0.3223, -0.2399, -0.3253, -0.2093, -0.3278, -0.2432, -0.4131, -0.1627,
#         -0.3783, -0.4014, -0.3009, -0.3258, -0.2829, -0.3163, -0.3715, -0.3698,
#         -0.2455, -0.2509, -0.1737, -0.3306], device='cuda:0',
#        requires_grad=True)
# Opt step: 144	 Avg reward: 118.77	 std: Parameter containing:
# tensor([-0.3271, -0.2343, -0.3257, -0.2112, -0.3234, -0.2324, -0.4125, -0.1701,
#         -0.3753, -0.4099, -0.3054, -0.3340, -0.2879, -0.3178, -0.3682, -0.3588,
#         -0.2456, -0.2452, -0.1786, -0.3386], device='cuda:0',
#        requires_grad=True)
# Opt step: 145	 Avg reward: 119.50	 std: Parameter containing:
# tensor([-0.3374, -0.2417, -0.3199, -0.2103, -0.3331, -0.2283, -0.4096, -0.1760,
#         -0.3751, -0.4118, -0.3000, -0.3399, -0.2831, -0.3187, -0.3799, -0.3588,
#         -0.2434, -0.2456, -0.1778, -0.3346], device='cuda:0',
#        requires_grad=True)
# Opt step: 146	 Avg reward: 123.58	 std: Parameter containing:
# tensor([-0.3439, -0.2378, -0.3181, -0.2165, -0.3395, -0.2292, -0.4096, -0.1729,
#         -0.3833, -0.4172, -0.3013, -0.3424, -0.2839, -0.3218, -0.3956, -0.3541,
#         -0.2391, -0.2509, -0.1709, -0.3443], device='cuda:0',
#        requires_grad=True)
# Opt step: 147	 Avg reward: 155.87	 std: Parameter containing:
# tensor([-0.3439, -0.2424, -0.3158, -0.2180, -0.3397, -0.2282, -0.4163, -0.1777,
#         -0.3881, -0.4105, -0.3061, -0.3426, -0.2857, -0.3245, -0.4005, -0.3572,
#         -0.2363, -0.2422, -0.1760, -0.3472], device='cuda:0',
#        requires_grad=True)
# Opt step: 148	 Avg reward: 124.10	 std: Parameter containing:
# tensor([-0.3419, -0.2494, -0.3227, -0.2143, -0.3381, -0.2427, -0.4147, -0.1834,
#         -0.3945, -0.4170, -0.3078, -0.3300, -0.2804, -0.3263, -0.4137, -0.3577,
#         -0.2393, -0.2374, -0.1835, -0.3492], device='cuda:0',
#        requires_grad=True)
# Opt step: 149	 Avg reward: 133.92	 std: Parameter containing:
# tensor([-0.3417, -0.2560, -0.3269, -0.2106, -0.3396, -0.2519, -0.4184, -0.1881,
#         -0.4110, -0.4059, -0.3054, -0.3331, -0.2800, -0.3161, -0.4167, -0.3642,
#         -0.2373, -0.2353, -0.1810, -0.3542], device='cuda:0',
#        requires_grad=True)
# Opt step: 150	 Avg reward: 132.16	 std: Parameter containing:
# tensor([-0.3499, -0.2707, -0.3341, -0.2125, -0.3399, -0.2496, -0.4232, -0.1878,
#         -0.4179, -0.4115, -0.3063, -0.3320, -0.2800, -0.3298, -0.4205, -0.3693,
#         -0.2320, -0.2394, -0.1766, -0.3653], device='cuda:0',
#        requires_grad=True)
# Opt step: 151	 Avg reward: 141.22	 std: Parameter containing:
# tensor([-0.3434, -0.2646, -0.3352, -0.2105, -0.3391, -0.2432, -0.4176, -0.1855,
#         -0.4170, -0.4183, -0.3105, -0.3349, -0.2847, -0.3368, -0.4286, -0.3735,
#         -0.2216, -0.2367, -0.1835, -0.3596], device='cuda:0',
#        requires_grad=True)
# Opt step: 152	 Avg reward: 133.79	 std: Parameter containing:
# tensor([-0.3374, -0.2590, -0.3340, -0.2041, -0.3322, -0.2450, -0.4192, -0.1776,
#         -0.4224, -0.4164, -0.3108, -0.3391, -0.2919, -0.3292, -0.4272, -0.3735,
#         -0.2195, -0.2322, -0.1956, -0.3506], device='cuda:0',
#        requires_grad=True)
# Opt step: 153	 Avg reward: 137.74	 std: Parameter containing:
# tensor([-0.3331, -0.2524, -0.3321, -0.2078, -0.3400, -0.2362, -0.4110, -0.1864,
#         -0.4333, -0.4175, -0.3117, -0.3430, -0.2981, -0.3398, -0.4325, -0.3751,
#         -0.2208, -0.2280, -0.1983, -0.3545], device='cuda:0',
#        requires_grad=True)
# Opt step: 154	 Avg reward: 140.29	 std: Parameter containing:
# tensor([-0.3376, -0.2531, -0.3216, -0.2161, -0.3407, -0.2379, -0.4058, -0.1943,
#         -0.4244, -0.4164, -0.3179, -0.3482, -0.2933, -0.3299, -0.4421, -0.3828,
#         -0.2109, -0.2303, -0.2074, -0.3450], device='cuda:0',
#        requires_grad=True)
# Opt step: 155	 Avg reward: 142.12	 std: Parameter containing:
# tensor([-0.3391, -0.2538, -0.3091, -0.2181, -0.3334, -0.2339, -0.4040, -0.2023,
#         -0.4356, -0.4201, -0.3234, -0.3395, -0.2800, -0.3293, -0.4380, -0.3889,
#         -0.2151, -0.2418, -0.2074, -0.3535], device='cuda:0',
#        requires_grad=True)
# Opt step: 156	 Avg reward: 143.10	 std: Parameter containing:
# tensor([-0.3285, -0.2635, -0.3131, -0.2225, -0.3196, -0.2223, -0.3986, -0.2060,
#         -0.4270, -0.4223, -0.3233, -0.3472, -0.2779, -0.3197, -0.4296, -0.3876,
#         -0.2086, -0.2365, -0.2089, -0.3492], device='cuda:0',
#        requires_grad=True)
# ...
#         -7.3049e-01, -8.1907e-01, -2.3010e-02,  1.9807e-01,  3.1080e-01,
#          1.9289e-01,  1.2737e-01, -2.6541e-02,  5.8284e-02,  4.0447e-02],
#        device='cuda:0', requires_grad=True)
# Opt step: 765	 Avg reward: 170.09	 std: Parameter containing:
# tensor([-0.3058,  0.1251, -0.0734,  0.2950, -0.5608,  0.2173, -0.2874, -0.0025,
#         -0.2656, -0.5142, -0.7242, -0.8222, -0.0256,  0.2019,  0.2882,  0.2009,
#          0.1303, -0.0391,  0.0746,  0.0432], device='cuda:0',
#        requires_grad=True)
# Opt step: 766	 Avg reward: 146.98	 std: Parameter containing:
# tensor([-0.3135,  0.1256, -0.0767,  0.3012, -0.5579,  0.2134, -0.2866,  0.0119,
#         -0.2589, -0.5152, -0.7209, -0.8176, -0.0264,  0.2053,  0.2834,  0.2049,
#          0.1221, -0.0365,  0.0745,  0.0399], device='cuda:0',
#        requires_grad=True)
# Opt step: 767	 Avg reward: 174.77	 std: Parameter containing:
# tensor([-0.3107,  0.1043, -0.0665,  0.3026, -0.5734,  0.2160, -0.2902,  0.0174,
#         -0.2506, -0.5146, -0.7234, -0.8258, -0.0242,  0.2078,  0.2949,  0.2067,
#          0.1037, -0.0154,  0.0846,  0.0392], device='cuda:0',
#        requires_grad=True)
# Opt step: 768	 Avg reward: 141.83	 std: Parameter containing:
# tensor([-0.3153,  0.1218, -0.0688,  0.2947, -0.5794,  0.2298, -0.2819,  0.0205,
#         -0.2651, -0.5102, -0.7089, -0.8284, -0.0207,  0.2240,  0.2882,  0.2015,
#          0.1092, -0.0164,  0.0974,  0.0261], device='cuda:0',
#        requires_grad=True)
# Opt step: 769	 Avg reward: 159.27	 std: Parameter containing:
# tensor([-0.3187,  0.1238, -0.0808,  0.2924, -0.5907,  0.2292, -0.2670,  0.0114,
#         -0.2690, -0.5128, -0.7141, -0.8298, -0.0269,  0.2160,  0.2950,  0.1939,
#          0.1081, -0.0127,  0.0982,  0.0397], device='cuda:0',
#        requires_grad=True)
# Opt step: 770	 Avg reward: 171.89	 std: Parameter containing:
# tensor([-0.3282,  0.1254, -0.0814,  0.2870, -0.5821,  0.2117, -0.2684,  0.0116,
#         -0.2690, -0.5196, -0.7155, -0.8297, -0.0191,  0.2246,  0.2890,  0.1991,
#          0.1007, -0.0029,  0.0886,  0.0478], device='cuda:0',
#        requires_grad=True)
# Opt step: 771	 Avg reward: 182.68	 std: Parameter containing:
# tensor([-0.3285,  0.1164, -0.0728,  0.2898, -0.5711,  0.1969, -0.2773,  0.0062,
#         -0.2860, -0.5269, -0.7109, -0.8387, -0.0247,  0.2256,  0.2827,  0.2146,
#          0.1075, -0.0108,  0.0768,  0.0530], device='cuda:0',
#        requires_grad=True)
# Opt step: 772	 Avg reward: 161.14	 std: Parameter containing:
# tensor([-0.3313,  0.1230, -0.0756,  0.2902, -0.5731,  0.1962, -0.2675,  0.0057,
#         -0.2923, -0.5197, -0.7109, -0.8418, -0.0336,  0.2347,  0.2853,  0.2057,
#          0.1018, -0.0121,  0.0909,  0.0408], device='cuda:0',
#        requires_grad=True)
# Opt step: 773	 Avg reward: 177.04	 std: Parameter containing:
# tensor([-0.3382,  0.1148, -0.0722,  0.2782, -0.5723,  0.2024, -0.2721,  0.0071,
#         -0.3090, -0.5261, -0.7140, -0.8237, -0.0452,  0.2264,  0.2811,  0.1959,
#          0.0953, -0.0168,  0.0877,  0.0348], device='cuda:0',
#        requires_grad=True)
# Opt step: 774	 Avg reward: 165.31	 std: Parameter containing:
# tensor([-0.3402,  0.1187, -0.0874,  0.2734, -0.5768,  0.1938, -0.2676,  0.0104,
#         -0.3096, -0.5323, -0.7119, -0.8121, -0.0540,  0.2259,  0.2890,  0.1943,
#          0.0902, -0.0276,  0.0937,  0.0292], device='cuda:0',
#        requires_grad=True)
# Opt step: 775	 Avg reward: 145.71	 std: Parameter containing:
# tensor([-0.3440,  0.1349, -0.0899,  0.2717, -0.5745,  0.1922, -0.2752,  0.0219,
#         -0.2954, -0.5156, -0.7140, -0.8183, -0.0611,  0.2304,  0.2802,  0.1878,
#          0.0918, -0.0407,  0.0918,  0.0348], device='cuda:0',
#        requires_grad=True)
# Opt step: 776	 Avg reward: 149.63	 std: Parameter containing:
# tensor([-0.3439,  0.1350, -0.0883,  0.2679, -0.5829,  0.1910, -0.2705,  0.0243,
#         -0.3049, -0.5190, -0.7073, -0.8221, -0.0558,  0.2332,  0.2829,  0.1927,
#          0.0943, -0.0454,  0.1013,  0.0267], device='cuda:0',
#        requires_grad=True)
# Opt step: 777	 Avg reward: 144.66	 std: Parameter containing:
# tensor([-0.3498,  0.1347, -0.0998,  0.2646, -0.5795,  0.1724, -0.2661,  0.0222,
#         -0.3085, -0.5232, -0.7090, -0.8233, -0.0633,  0.2333,  0.2909,  0.1949,
#          0.0862, -0.0421,  0.1035,  0.0113], device='cuda:0',
#        requires_grad=True)
# Opt step: 778	 Avg reward: 150.61	 std: Parameter containing:
# tensor([-0.3485,  0.1521, -0.1051,  0.2677, -0.5823,  0.1665, -0.2749,  0.0145,
#         -0.2945, -0.5280, -0.7205, -0.8257, -0.0680,  0.2316,  0.2792,  0.2002,
#          0.0739, -0.0396,  0.0972, -0.0049], device='cuda:0',
#        requires_grad=True)
# Opt step: 779	 Avg reward: 136.95	 std: Parameter containing:
# tensor([-0.3496,  0.1452, -0.1013,  0.2772, -0.5778,  0.1796, -0.2927,  0.0043,
#         -0.2946, -0.5262, -0.7159, -0.8259, -0.0725,  0.2216,  0.2702,  0.1985,
#          0.0641, -0.0489,  0.1076, -0.0228], device='cuda:0',
#        requires_grad=True)
# Opt step: 780	 Avg reward: 145.81	 std: Parameter containing:
# tensor([-0.3610,  0.1480, -0.1020,  0.2629, -0.5886,  0.1810, -0.2851,  0.0199,
#         -0.2841, -0.5217, -0.7179, -0.8237, -0.0722,  0.2271,  0.2735,  0.2062,
#          0.0624, -0.0426,  0.1135, -0.0155], device='cuda:0',
#        requires_grad=True)
# Opt step: 781	 Avg reward: 158.19	 std: Parameter containing:
# tensor([-0.3718,  0.1440, -0.1000,  0.2540, -0.5840,  0.1787, -0.2850,  0.0108,
#         -0.2829, -0.5146, -0.7087, -0.8153, -0.0620,  0.2241,  0.2811,  0.1948,
#          0.0560, -0.0396,  0.1165, -0.0192], device='cuda:0',
#        requires_grad=True)
# Opt step: 782	 Avg reward: 142.37	 std: Parameter containing:
# tensor([-0.3717,  0.1380, -0.1035,  0.2462, -0.5971,  0.1794, -0.2887,  0.0026,
#         -0.2903, -0.5128, -0.7028, -0.8168, -0.0489,  0.2234,  0.2873,  0.1858,
#          0.0561, -0.0468,  0.1053, -0.0224], device='cuda:0',
#        requires_grad=True)
# Opt step: 783	 Avg reward: 142.29	 std: Parameter containing:
# tensor([-0.3791,  0.1544, -0.1078,  0.2496, -0.6032,  0.1822, -0.2918, -0.0122,
#         -0.2942, -0.5139, -0.7232, -0.8244, -0.0581,  0.2172,  0.2931,  0.1697,
#          0.0513, -0.0546,  0.1082, -0.0187], device='cuda:0',
#        requires_grad=True)
# Opt step: 784	 Avg reward: 131.42	 std: Parameter containing:
# tensor([-0.3832,  0.1530, -0.1079,  0.2541, -0.6044,  0.1729, -0.2885, -0.0023,
#         -0.2786, -0.5009, -0.7260, -0.8247, -0.0544,  0.2148,  0.2979,  0.1612,
#          0.0415, -0.0595,  0.1024, -0.0249], device='cuda:0',
#        requires_grad=True)
# Opt step: 785	 Avg reward: 133.40	 std: Parameter containing:
# tensor([-0.3846,  0.1463, -0.1072,  0.2546, -0.5980,  0.1723, -0.3049,  0.0077,
#         -0.2823, -0.5037, -0.7211, -0.8288, -0.0600,  0.2206,  0.3063,  0.1632,
#          0.0447, -0.0637,  0.1120, -0.0239], device='cuda:0',
#        requires_grad=True)
# Opt step: 786	 Avg reward: 139.91	 std: Parameter containing:
# tensor([-0.3834,  0.1448, -0.1191,  0.2587, -0.5942,  0.1706, -0.3235,  0.0040,
#         -0.2815, -0.5174, -0.7197, -0.8411, -0.0601,  0.2269,  0.3132,  0.1502,
#          0.0440, -0.0649,  0.1032, -0.0324], device='cuda:0',
#        requires_grad=True)
# Opt step: 791	 Avg reward: 147.21	 std: Parameter containing:
# tensor([-0.4067,  0.1170, -0.1379,  0.2623, -0.6039,  0.1793, -0.3064, -0.0043,
#         -0.2546, -0.5089, -0.7128, -0.8484, -0.0651,  0.2099,  0.2863,  0.1434,
#          0.0522, -0.1091,  0.0998, -0.0155], device='cuda:0',
#        requires_grad=True)
# Opt step: 792	 Avg reward: 137.89	 std: Parameter containing:
# tensor([-0.4101,  0.1194, -0.1321,  0.2762, -0.5968,  0.1791, -0.3097, -0.0022,
#         -0.2471, -0.5017, -0.7015, -0.8496, -0.0668,  0.2053,  0.3053,  0.1372,
#          0.0509, -0.0914,  0.1002, -0.0139], device='cuda:0',
#        requires_grad=True)
# Opt step: 793	 Avg reward: 148.30	 std: Parameter containing:
# tensor([-0.4107,  0.1188, -0.1385,  0.2775, -0.6064,  0.1902, -0.3185, -0.0029,
#         -0.2315, -0.4969, -0.6960, -0.8531, -0.0585,  0.2046,  0.3055,  0.1429,
#          0.0496, -0.1020,  0.1137, -0.0257], device='cuda:0',
#        requires_grad=True)
# Opt step: 794	 Avg reward: 161.33	 std: Parameter containing:
# tensor([-0.4110,  0.1180, -0.1389,  0.2970, -0.6084,  0.1917, -0.3158,  0.0090,
#         -0.2321, -0.4851, -0.6962, -0.8572, -0.0778,  0.1992,  0.3062,  0.1365,
#          0.0473, -0.1054,  0.1174, -0.0210], device='cuda:0',
#        requires_grad=True)
# Opt step: 795	 Avg reward: 182.90	 std: Parameter containing:
# tensor([-0.4141,  0.1268, -0.1375,  0.2989, -0.5986,  0.1866, -0.3091,  0.0288,
#         -0.2411, -0.4767, -0.7105, -0.8521, -0.0798,  0.1957,  0.3114,  0.1322,
#          0.0405, -0.1121,  0.1091, -0.0092], device='cuda:0',
#        requires_grad=True)
# Opt step: 796	 Avg reward: 164.53	 std: Parameter containing:
# tensor([-0.3982,  0.1455, -0.1480,  0.3020, -0.6069,  0.1824, -0.3033,  0.0221,
#         -0.2379, -0.4784, -0.7010, -0.8540, -0.0823,  0.1880,  0.3064,  0.1357,
#          0.0598, -0.1091,  0.1198, -0.0155], device='cuda:0',
#        requires_grad=True)
# Opt step: 797	 Avg reward: 147.81	 std: Parameter containing:
# tensor([-0.3961,  0.1439, -0.1336,  0.2947, -0.6157,  0.1870, -0.3161,  0.0389,
#         -0.2435, -0.4884, -0.7133, -0.8651, -0.0897,  0.1853,  0.3013,  0.1371,
#          0.0632, -0.1110,  0.1138, -0.0146], device='cuda:0',
#        requires_grad=True)
# Opt step: 798	 Avg reward: 174.71	 std: Parameter containing:
# tensor([-0.4024,  0.1358, -0.1328,  0.3028, -0.6149,  0.1971, -0.3167,  0.0328,
#         -0.2393, -0.4799, -0.7230, -0.8656, -0.0828,  0.1962,  0.3123,  0.1373,
#          0.0763, -0.1184,  0.1267, -0.0027], device='cuda:0',
#        requires_grad=True)
# Opt step: 799	 Avg reward: 166.81	 std: Parameter containing:
# tensor([-0.4085,  0.1439, -0.1410,  0.2977, -0.6081,  0.1948, -0.3170,  0.0228,
#         -0.2461, -0.4767, -0.7081, -0.8637, -0.0767,  0.2060,  0.3007,  0.1299,
#          0.0711, -0.1176,  0.1218, -0.0106], device='cuda:0',
#        requires_grad=True)
# Opt step: 800	 Avg reward: 154.25	 std: Parameter containing:
# tensor([-4.0332e-01,  1.4117e-01, -1.4485e-01,  2.8757e-01, -5.9473e-01,
#          1.8819e-01, -3.2368e-01,  2.7378e-02, -2.3616e-01, -4.6947e-01,
#         -7.0537e-01, -8.6887e-01, -7.4233e-02,  2.1484e-01,  2.9979e-01,
#          1.2192e-01,  7.2525e-02, -1.1110e-01,  1.2516e-01, -7.3414e-04],
#        device='cuda:0', requires_grad=True)
# Opt step: 801	 Avg reward: 164.14	 std: Parameter containing:
# tensor([-0.4038,  0.1399, -0.1528,  0.2901, -0.5891,  0.1715, -0.3378,  0.0173,
#         -0.2270, -0.4544, -0.7061, -0.8662, -0.0592,  0.2146,  0.3077,  0.1220,
#          0.0720, -0.1001,  0.1277,  0.0077], device='cuda:0',
#        requires_grad=True)
# Opt step: 802	 Avg reward: 147.60	 std: Parameter containing:
# tensor([-0.4092,  0.1343, -0.1610,  0.2938, -0.5858,  0.1668, -0.3457,  0.0258,
#         -0.2026, -0.4549, -0.7017, -0.8613, -0.0511,  0.2040,  0.3041,  0.1356,
#          0.0768, -0.1114,  0.1254,  0.0031], device='cuda:0',
#        requires_grad=True)
# Opt step: 803	 Avg reward: 144.75	 std: Parameter containing:
# tensor([-0.4017,  0.1360, -0.1717,  0.2896, -0.5854,  0.1693, -0.3564,  0.0282,
#         -0.2051, -0.4438, -0.6944, -0.8575, -0.0542,  0.2020,  0.3018,  0.1446,
#          0.0599, -0.1105,  0.1342, -0.0046], device='cuda:0',
#        requires_grad=True)
# Opt step: 804	 Avg reward: 170.29	 std: Parameter containing:
# tensor([-0.4040,  0.1231, -0.1665,  0.2799, -0.5889,  0.1657, -0.3552,  0.0165,
#         -0.1964, -0.4402, -0.6951, -0.8556, -0.0578,  0.2108,  0.2824,  0.1456,
#          0.0541, -0.1080,  0.1491, -0.0124], device='cuda:0',
#        requires_grad=True)
# Opt step: 805	 Avg reward: 136.69	 std: Parameter containing:
# tensor([-0.4128,  0.1205, -0.1652,  0.2654, -0.5964,  0.1603, -0.3573,  0.0230,
#         -0.2012, -0.4419, -0.6977, -0.8596, -0.0579,  0.2068,  0.2692,  0.1431,
#          0.0532, -0.1132,  0.1505, -0.0077], device='cuda:0',
#        requires_grad=True)
# Opt step: 806	 Avg reward: 155.60	 std: Parameter containing:
# tensor([-0.4250,  0.1114, -0.1723,  0.2631, -0.5963,  0.1518, -0.3678,  0.0224,
#         -0.2002, -0.4564, -0.6912, -0.8609, -0.0553,  0.1930,  0.2735,  0.1578,
#          0.0635, -0.1118,  0.1539, -0.0069], device='cuda:0',
#        requires_grad=True)
# Opt step: 807	 Avg reward: 149.88	 std: Parameter containing:
# tensor([-0.4307,  0.1184, -0.1694,  0.2631, -0.5943,  0.1483, -0.3567,  0.0305,
#         -0.2040, -0.4594, -0.6908, -0.8734, -0.0381,  0.1746,  0.2824,  0.1746,
#          0.0738, -0.1209,  0.1662, -0.0064], device='cuda:0',
#        requires_grad=True)
# Opt step: 808	 Avg reward: 161.95	 std: Parameter containing:
# tensor([-0.4261,  0.1057, -0.1660,  0.2558, -0.6030,  0.1634, -0.3579,  0.0257,
#         -0.2099, -0.4541, -0.6921, -0.8688, -0.0425,  0.1796,  0.2791,  0.1725,
#          0.0872, -0.1127,  0.1615, -0.0049], device='cuda:0',
#        requires_grad=True)
# Opt step: 809	 Avg reward: 162.18	 std: Parameter containing:
# tensor([-0.4316,  0.1025, -0.1695,  0.2502, -0.6106,  0.1553, -0.3454,  0.0254,
#         -0.2203, -0.4654, -0.6952, -0.8579, -0.0313,  0.1880,  0.3010,  0.1673,
#          0.0793, -0.1299,  0.1582,  0.0028], device='cuda:0',
#        requires_grad=True)
# Opt step: 810	 Avg reward: 184.00	 std: Parameter containing:
# tensor([-0.4325,  0.1008, -0.1598,  0.2452, -0.6124,  0.1589, -0.3546,  0.0183,
#         -0.2163, -0.4686, -0.7013, -0.8585, -0.0404,  0.1814,  0.2957,  0.1750,
#          0.0835, -0.1225,  0.1664,  0.0087], device='cuda:0',
#        requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-5b164e5097d5> in <module>
# ----> 1 scores = agent.train(max_opt_steps=2000,gamma=0.98,target_score=2000,use_gae=True,PRINT_EVERY=1)
#
# <ipython-input-35-7916f30cf0d2> in train(self, max_opt_steps, num_trajectories, rollout_length, mini_batch_size, gamma, target_score, use_gae, gae_tau, PRINT_EVERY)
#      42
#      43                 # send all actions to tne environment
# ---> 44                 next_states,rewards,terminals,_ = self.env.step(list(prediction['a'].cpu().numpy()))
#      45
#      46                 next_states = np.array(next_states)
#
# ~/anaconda3/envs/cv3/lib/python3.6/site-packages/gym_unity/envs/unity_env.py in step(self, action)
#     129                 action = np.array(action)
#     130
# --> 131         info = self._env.step(action)[self.brain_name]
#     132         n_agents = len(info.agents)
#     133         self._check_agents(n_agents)
#
# ~/learning/ml-agents/ml-agents/mlagents/envs/environment.py in step(self, vector_action, memory, text_action, value)
#     390
#     391             outputs = self.communicator.exchange(
# --> 392                 self._generate_step_input(vector_action, memory, text_action, value))
#     393             if outputs is None:
#     394                 raise KeyboardInterrupt
#
# ~/learning/ml-agents/ml-agents/mlagents/envs/rpc_communicator.py in exchange(self, inputs)
#      94         message.unity_input.CopyFrom(inputs)
#      95         self.unity_to_external.parent_conn.send(message)
# ---> 96         output = self.unity_to_external.parent_conn.recv()
#      97         if output.header.status != 200:
#      98             return None
#
# ~/anaconda3/envs/cv3/lib/python3.6/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/anaconda3/envs/cv3/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/envs/cv3/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
frames = []
total_rewards = np.zeros(12)

# reset the environment
env_info = env.reset(train_mode=True)[brain_name]
states = np.array(env_info.vector_observations)
value = []
r = []
for t in range(2000):
    prediction = agent.policy.act(states)
    action  = prediction['a'].cpu().numpy()
    v = prediction['v'].detach().cpu().numpy()
    frames.append(env.render(mode='rgb_array')) 
    
    
    # send all actions to tne environment
    env_info = self.env.step((prediction['a']).cpu().numpy())[brain_name]

    next_states = np.array(env_info.vector_observations)         # get next state (for each agent)
    rewards = np.array(env_info.rewards)                         # get reward (for each agent)
    terminals = np.array(env_info.local_done)                    # see if episode finished
    
    #value.append(v.squeeze())
    #r.append(reward)
    states=next_states
    total_rewards+= rewards
    for i,terminal in terminals:
        if terminal:
            eps_reward = total_rewards[i]
            break

print ("Total reward:",eps_rewards)
env.close()
#animate_frames(frames)
